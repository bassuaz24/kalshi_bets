# %% [markdown]
# # View filtered winners and spreads
#
# Loads the most recent `filtered_winners_*.csv` and `filtered_spreads_*.csv` from `analysis_outputs/` and displays them as DataFrames.

# %%
from pathlib import Path
import pandas as pd

# Resolve analysis_outputs alongside this notebook; fall back to cwd if __file__ is not defined.
try:
    base = Path(__file__).resolve().parent / "analysis_outputs"
except NameError:
    base = Path.cwd() / "analysis_outputs"

def latest_csv(pattern: str):
    files = list(base.glob(pattern))
    if not files:
        return None
    return max(files, key=lambda p: p.stat().st_mtime)

winners_path = latest_csv("filtered_winners_*.csv")
spreads_path = latest_csv("filtered_spreads_*.csv")

print(f"Winners CSV: {winners_path}")
print(f"Spreads CSV: {spreads_path}")

if winners_path:
    winners_df = pd.read_csv(winners_path)
    display(winners_df)
else:
    print("No winners CSV found.")

if spreads_path:
    spreads_df = pd.read_csv(spreads_path)
    display(spreads_df)
else:
    print("No spreads CSV found.")
# Out:
# Winners CSV: /Users/Brett/kdata/kalshi_bets/live_betting/analysis_outputs/filtered_winners_2025-11-25.csv
# Spreads CSV: /Users/Brett/kdata/kalshi_bets/live_betting/analysis_outputs/filtered_spreads_2025-11-25.csv
#                                ticker  yes_bid  yes_ask    kalshi_home_team  \
# 0      KXNCAAMBGAME-25NOV25WSUASU-WSU     0.25     0.27          Arizona St
# 1     KXNCAAMBGAME-25NOV25MICHAUB-AUB     0.32     0.34              Auburn
# 2     KXNCAAMBGAME-25NOV25UCLACAL-CAL     0.22     0.23          California
# 3      KXNCAAMBGAME-25NOV25EWUUNT-EWU     0.11     0.13         North Texas
# 4      KXNCAAMBGAME-25NOV25KSUIND-KSU     0.17     0.18             Indiana
# 5       KXNCAAMBGAME-25NOV25MDGONZ-MD     0.08     0.09             Gonzaga
# 6       KXNCAAMBGAME-25NOV25MDGONZ-MD     0.08     0.09             Gonzaga
# 7     KXNCAAMBGAME-25NOV25MICHAUB-AUB     0.32     0.34              Auburn
# 8      KXNCAAMBGAME-25NOV25WINNEB-WIN     0.08     0.09            Nebraska
# 9    KXNCAAMBGAME-25NOV25SBONUNC-SBON     0.13     0.15      North Carolina
# 10     KXNCAAMBGAME-25NOV25EWUUNT-EWU     0.11     0.13         North Texas
# 11    KXNCAAMBGAME-25NOV25ODUVILL-ODU     0.03     0.05           Villanova
# 12  KXNCAAMBGAME-25NOV25MISSIOWA-MISS     0.33     0.34                Iowa
# 13   KXNCAAMBGAME-25NOV25ORESDSU-SDSU     0.42     0.45        San Diego St
# 14  KXNCAAMBGAME-25NOV25RICEFGCU-RICE     0.29     0.31  Florida Gulf Coast
# 15    KXNCAAMBGAME-25NOV25NDRUTG-RUTG     0.16     0.17             Rutgers
# 16   KXNCAAMBGAME-25NOV25SBONUNC-SBON     0.13     0.15      North Carolina
# 17      KXNCAAMBGAME-25NOV25SYRKU-SYR     0.31     0.33              Kansas
# 18  KXNCAAMBGAME-25NOV25TLSASJSU-TLSA     0.67     0.68         San Jose St
#
#       kalshi_away_team market               start_time  \
# 12                Ole Miss Rebels        0.3541   0.002609    0.002609
# 13                   Oregon Ducks        0.5549   0.019278    0.019278
# 14                      Rice Owls        0.3318   0.004127    0.004127
# 15      Notre Dame Fighting Irish        0.3054   0.015274    0.015274
# 16        St. Bonaventure Bonnies        0.1597   0.002081    0.002081
# 17                Syracuse Orange        0.3936   0.009832    0.009832
# 18         Tulsa Golden Hurricane        0.7002   0.007044    0.007044
#
#     optimal_bet  num_contracts  trading_cost   profit       ev
# 0     84.230236          336.0          1.11   250.89   164.16
# 1      5.239244           16.0          0.07    10.81     0.49
# 2      2.423485           11.0          0.04     8.54     0.20
# 3      2.487586           22.0          0.04    19.54     0.53
# 4      5.008537           29.0          0.08    23.99     0.99
# 5      2.293338           28.0          0.04    25.72     0.54
# 6     47.523057          594.0          0.77   545.71   202.05
# 7     60.492966          189.0          0.72   127.80    60.56
# 8    118.234307         1477.0          1.91  1356.93  1239.21
# 9     25.770668          198.0          0.40   171.86    35.71
# 10   109.380199          994.0          1.71   882.95   747.10
# 11     2.509665           83.0          0.05    80.46     2.35
# 12     3.720367           11.0          0.05     7.32     0.19
# 13    27.488108           65.0          0.28    37.42     8.53
# 14     5.884414           20.0          0.08    14.12     0.75
# 15    21.779843          136.0          0.32   113.92    19.66
# 16     2.967166           22.0          0.05    19.09     0.56
# 17    14.019839           45.0          0.17    30.88     3.65
# 18    10.043644           14.0          0.06     4.56     0.18
#                                  ticker  yes_bid  yes_ask              team  \
# 0     KXNCAAMBSPREAD-25NOV25FAUGMU-FAU5     0.15     0.22  Florida Atlantic
# 1    KXNCAAMBSPREAD-25NOV25NCSTBSU-BSU6     0.03     0.50          Boise St
# 2  KXNCAAMBSPREAD-25NOV25MISSIOWA-MISS4     0.20     0.39          Ole Miss
# 3    KXNCAAMBSPREAD-25NOV25NDRUTG-RUTG6     0.03     0.40           Rutgers
#
#    points   market               start_time                odds_team  \
# 0     5.5  spreads  2025-11-25 18:30:38 CST    Florida Atlantic Owls
# 1     6.5  spreads  2025-11-25 13:30:17 CST      Boise State Broncos
# 2     4.5  spreads  2025-11-25 20:30:00 CST          Ole Miss Rebels
# 3     6.5  spreads  2025-11-25 12:00:00 CST  Rutgers Scarlet Knights
#
#             odds_home_team             odds_away_team  avg_fair_prb  point  \
# 0    Florida Atlantic Owls      George Mason Patriots        0.5050    5.5
# 1      Boise State Broncos          NC State Wolfpack        0.5118    6.5
# 2            Iowa Hawkeyes            Ole Miss Rebels        0.4966    4.5
# 3  Rutgers Scarlet Knights  Notre Dame Fighting Irish        0.5210    6.5
#
#    raw_kelly  real_kelly  optimal_bet  num_contracts  trading_cost   profit  \
# 0   0.215338    0.215338   131.592953          877.0          1.96   743.49
# 1   0.184156    0.184156   112.537711         3751.0          1.92  3636.55
# 2   0.156830    0.156830    95.838868          479.0          1.35   381.85
# 3   0.213786    0.213786   130.644771         4354.0          2.22  4221.16
#
#         ev
# 0   310.32
# 1  1806.25
# 2   141.38
# 3  2136.65
